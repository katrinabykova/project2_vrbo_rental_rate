# %%
import requests
import time
import pickle
import io
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.model_selection import *  # be more specific
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV, ElasticNetCV, ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, explained_variance_score
from sklearn.preprocessing import StandardScaler, PowerTransformer
from sklearn.model_selection import cross_val_score, train_test_split, KFold 
from geopy.geocoders import Nominatim
from sklearn.preprocessing import FunctionTransformer, StandardScaler, PolynomialFeatures, PowerTransformer
from sklearn.pipeline import FeatureUnion, make_pipeline
from sklearn_pandas import DataFrameMapper
import scipy.stats as stats
from sklearn.feature_selection import RFE
import statsmodels.api as sm

# %% [markdown]
# ## Load data

# %%
# Unpickle data  
with open('df3.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
df.columns.to_list()
# Out:
# ['property_id',
#  'price',
#  'guests',
#  'bedrooms',
#  'beds',
#  'baths',
#  'latitude',
#  'longitude',
#  'review_rate',
#  'review_num',
#  'property_type',
#  'link',
#  'price_log',
#  'bedrooms_inc',
#  'property_type_inc',
#  'Entire apartment',
#  'Entire guest suite',
#  'Entire house',
#  'Private room in apartment',
#  'Private room in house',
#  'coordinates',
#  'address',
#  'hood',
#  'zip',
#  'ballard',
#  'beacon hill',
#  'burien',
#  'capitol hill',
#  'central district',
#  'delridge',
#  'downtown',
#  'fremont',
#  'green lake',
#  'lake city',
#  'lake union',
#  'magnolia',
#  'north seattle',
#  'northgate',
#  'phinney ridge',
#  'queen anne',
#  'rainier valley',
#  'shoreline',
#  'south end',
#  'tukwila',
#  'university district',
#  'west seattle',
#  'white center']

# %% [markdown]
# ## Additional data cleaning

# %%
# Remove NaN
df = df.dropna()
df.shape
# Out:
# (1235, 47)

# %%
# Remove > 4 values for the number of baths (`baths`)
df['baths'].value_counts()
df.loc[df['baths'] > 4] = np.nan
df.dropna(inplace=True)
df.shape
# Out:
# (1235, 47)

# %%
# Remove > 7 values for the number of beds (`baths`)
df['beds'].value_counts()
df.loc[df['beds'] > 7] = np.nan
# df1.loc[df['beds'] == 0] = np.nan
df.dropna(inplace=True)
df.shape
# Out:
# (1235, 47)

# %%
df['zip'].astype(int)
# Out:
# 0       98136
# 1       98122
# 2       98121
# 3       98109
# 4       98108
#         ...
# 1310    98107
# 1311    98102
# 1312    98122
# 1313    98125
# 1314    98144
# Name: zip, Length: 1235, dtype: int64

# %%
plt.hist(df['price'])
# Out:
# (array([624., 473.,  95.,  25.,   8.,   5.,   1.,   3.,   0.,   1.]),
#  array([ 20. ,  87.9, 155.8, 223.7, 291.6, 359.5, 427.4, 495.3, 563.2,
#         631.1, 699. ]),
#  <a list of 10 Patch objects>)

# %%
df.loc[df['price']>600, ['price']]
# Out:
#       price
# 1013  699.0

# %%
df.loc[df['price']>600, ['price']] = np.nan

# %% [markdown]
# ## EDA

# %%
# Plot continuous variables 
sns.set(font_scale=2)
sns.pairplot(df.loc[:,
                 ['price', 'guests', 'beds', 'baths', 
                  'latitude', 'longitude', 'review_rate', 'review_num', 
                  'price_log', 'bedrooms_inc', 
                  'property_type_inc', 'zip']], 
             diag_kind='kde')
# plt.ylabel('y_test', fontsize=80)
# Out:
# /Users/greenapple/anaconda3/envs/metis/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /Users/greenapple/anaconda3/envs/metis/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
# Candidates for power transformation (target has been transformed already): 
'zip', 'bedrooms_inc', 'review_num', 'review_rate', 'baths', 'beds', 'guests'
# Out:
# ('zip', 'bedrooms_inc', 'review_num', 'review_rate', 'baths', 'beds', 'guests')

# %%
# Correlation matrix
sns.set(font_scale=1)
plt.subplots(figsize=(20,10))
hitmap = sns.heatmap(
    df.corr(), 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True)
hitmap.set_xticklabels(
    hitmap.get_xticklabels(),
    rotation=45,
    horizontalalignment='right');

# %%
# Explore correlations between features
sns.set(font_scale=1)
sns.lmplot(x='guests', y='beds', data=df, size=3)
sns.lmplot(x='beds', y='bedrooms_inc', data=df, size=3)
sns.lmplot(x='guests', y='bedrooms_inc', data=df, size=3)
# Out:
# /Users/greenapple/anaconda3/envs/metis/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# Correlation between potentially correlated features and the target
sns.set(font_scale=1)
sns.lmplot(x='guests', y='price_log', data=df, size=3)
sns.lmplot(x='beds', y='price_log', data=df, size=3)
sns.lmplot(x='bedrooms_inc', y='price_log', data=df, size=3)

# %%
# Try taking out `beds` to decrease correlation between features. 
# Result: decreased R2 a bit. Keep these features.

# %% [markdown]
# ## Linear Regression

# %%
# Set features and target
# Already removed redundant features, e.g `zip`, `latitude`, and `longitude`
X = df.loc[:, [
    'guests', 
    'baths', 
    'beds',
    'bedrooms_inc',
    'review_rate', 
    'review_num',
    'Entire apartment', 
    'Entire guest suite', 
    'Entire house',
    'Private room in apartment', 
    'Private room in house',
    'ballard', 'beacon hill', 'burien', 'capitol hill','central district', 'delridge', 'downtown', 'fremont', 
    'green lake','lake city', 'lake union', 'magnolia', 'north seattle', 'northgate','phinney ridge', 
    'queen anne', 'rainier valley', 'shoreline','south end', 'tukwila', 'university district', 'west seattle',
    'white center'
]]

y = df['price_log']

# %%
# Train and get model scores
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=10, shuffle=True)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train.values)
X_test_scaled = scaler.transform(X_test.values)
    
# Train 
classifier = LinearRegression()
classifier.fit(X_train_scaled, y_train)
    
# R2 for train
R2_train = classifier.score(X_train_scaled, y_train)
print('R2 train: ', R2_train)

# Predict
y_pred = classifier.predict(X_test_scaled)
    
# R2 for test
R2_test = r2_score(y_test, y_pred)
print('R2 test: ', R2_test)
    
residuals = y_test - y_pred
# Out:
# R2 train:  0.586294392172598
# R2 test:  0.5339798249000769

# %%
# Collect coefficients 

# Linear regression with no regularization
linreg_coef = classifier.coef_

# Ridge
classifier = LinearRegression()
classifier.fit(X_train_scaled, y_train)
classifier.predict(X_test_scaled)
ridge_coef = classifier.coef_

# %%
# Errors
MAE_log = mean_absolute_error(y_test, y_pred)
MAE = math.pow(10, MAE_log)
print('Mean Absolute Error: ', MAE)

RMSE_log = mean_squared_error(y_test, y_pred)
RMSE = math.pow(10, RMSE_log)
print('Root Mean Square Error: ', RMSE)  

# Mean
y_mean_log = y.mean()
y_mean = np.power(10, y_mean_log)
math.pow(10, y_mean_log)
print('Mean:', y_mean)
# Out:
# Mean Absolute Error:  1.2876830267077486
# Root Mean Square Error:  1.0505035352761762
# Mean: 85.73592008770314

# %%
# Errors: mean absolute precentage error (MAPE)
y_test_a  = np.power(10, np.array(y_test))
y_pred_a = np.power(10, y_pred)

AE = np.abs((y_test_a - y_pred_a) / y_test_a)
MAPE = np.mean(AE)*100
MAPE
# Out:
# 24.443909184634556

# %%
X.columns.to_list()
# Out:
# ['guests',
#  'baths',
#  'beds',
#  'bedrooms_inc',
#  'review_rate',
#  'review_num',
#  'Entire apartment',
#  'Entire guest suite',
#  'Entire house',
#  'Private room in apartment',
#  'Private room in house',
#  'ballard',
#  'beacon hill',
#  'burien',
#  'capitol hill',
#  'central district',
#  'delridge',
#  'downtown',
#  'fremont',
#  'green lake',
#  'lake city',
#  'lake union',
#  'magnolia',
#  'north seattle',
#  'northgate',
#  'phinney ridge',
#  'queen anne',
#  'rainier valley',
#  'shoreline',
#  'south end',
#  'tukwila',
#  'university district',
#  'west seattle',
#  'white center']

# %%
sns.set(font_scale=1.5)
# Plot results and evaluations
fig = sns.scatterplot(x=y_pred, y=y_test, alpha=.7, data=X_test)
plt.annotate(s='R2 =0.54', xy=(2.3, 1.4))
fig.set(xticklabels=[20, 40, 63, 100, 159, 250])
fig.set(yticklabels=[20, 56, 63, 100, 178, 316, 562])
plt.xlabel('Predicted price ($)')
plt.ylabel('Actual price ($)')
# plt.title('R2_train:' + str(R2_train) + '\n R2_test:'+ str(R2_test))
plt.savefig('lr.svg', bbox_inches = 'tight') 

plt.show()
    
# QQ plot
stats.probplot(residuals, dist="norm", plot=plt)
plt.title("Normal Q-Q plot");
plt.show()

fig_x = sns.scatterplot(x=y_pred, y=residuals, alpha=.7)
plt.xlabel('y_pred', fontsize=15)
plt.ylabel('residuals')
plt.title('')
# plt.savefig('lr.svg') 
plt.show()

# %%
# Function: take out
def linearreg(X_, y_):
    '''
    Function trains linear regression (without regularization) on X and y passed in as arguments.
    '''
    
    X_train, X_test, y_train, y_test = train_test_split(X_, y_, test_size=0.2,random_state=10, shuffle=True)

    scaler = StandardScaler()

    X_train_scaled = scaler.fit_transform(X_train.values)
    X_test_scaled = scaler.transform(X_test.values)
    
    # Train 
    classifier = LinearRegression()
    classifier.fit(X_train_scaled, y_train)
    
    # R2 for train
    R2_train = classifier.score(X_train_scaled, y_train)
    print('R2 train: ', R2_train)

    # Predict
    y_pred = classifier.predict(X_test_scaled)
    
    # R2 for test
    R2_test = r2_score(y_test, y_pred)
    print('R2 test: ', R2_test)
    
    residuals = y_test - y_pred
    
    score_dict = {'R2_train':R2_train, 'R2_test':R2_test}
    return score_dict

# %%
# Tried regularization (not shown) - no improvement of R2. Next - explore more complex models and 
# see if adding more observations would be beneficial.

# %% [markdown]
# ## Would adding additional observations be beneficial?

# %%
# Assess whether more observations would be benefitial for improving the model
params = []
sample_size = []

for df_slice in range(100, 1200, 100):
    df_set = df.loc[:df_slice,:]
    
    sample_size.append(df_slice)
    
    X_set = df_set.loc[:, [
    'guests', 
    'baths', 
    'beds',
    'bedrooms_inc',
    'review_rate', 
    'review_num',
    'Entire apartment', 
    'Entire guest suite', 
    'Entire house',
    'Private room in apartment', 
    'Private room in house',
    'ballard', 'beacon hill', 'burien', 'capitol hill','central district', 'delridge', 'downtown', 'fremont', 
    'green lake','lake city', 'lake union', 'magnolia', 'north seattle', 'northgate','phinney ridge', 
    'queen anne', 'rainier valley', 'shoreline','south end', 'tukwila', 'university district', 'west seattle',
    'white center'
    ]]

    y_set = df_set['price_log']
    
    a = linearreg(X_set, y_set)
    params.append(a);
# Out:
# R2 train:  0.5773875965199282
# R2 test:  0.060588215191787365
# R2 train:  0.5505949846193355
# R2 test:  -7.37364723791042e+26
# R2 train:  0.5451396283829701
# R2 test:  0.29921437212519264
# R2 train:  0.5579106258845521
# R2 test:  0.39170858376745965
# R2 train:  0.5485294288915924
# R2 test:  0.47927311721536936
# R2 train:  0.552038323764215
# R2 test:  -5.406399946449797e+20
# R2 train:  0.5400743294572103
# R2 test:  0.3634707635522578
# R2 train:  0.5334264607728483
# R2 test:  0.4350428746565286
# R2 train:  0.5176026736981485
# R2 test:  0.4576945325671732
# R2 train:  0.5187010381109181
# R2 test:  0.4785593916453582
# R2 train:  0.5654043431196651
# R2 test:  0.5345974030443256

# %%
# Arrange variables for plotting
R2_train_set = []
R2_test_set = []
for el in params:
     R2_train_set.append(el['R2_train'])
     R2_test_set.append(el['R2_test'])

R2_test_set = [x if x > 0 else np.nan for x in R2_test_set]

# %%
# Assess whether more observations would be benefitial for improving the model
sns.scatterplot(x=sample_size, y=R2_test_set, alpha=.7)
sns.scatterplot(x=sample_size, y=R2_train_set, alpha=.7)
plt.legend(('R2_test', 'R2_train'))
plt.xlabel('Sample size')
plt.yticks(np.arange(0, 1.1, 0.1))
plt.ylabel('R2')
plt.title('')
# plt.savefig('mvp.svg') 
plt.show()
# NB - replaced negative R2_test with 0

# %%
# Based on the R2 curves from test and train (above), adding more observations might not be the best use of time. 
# Look at increasing model complexity. 
# Adding more features is not time permitting at this point.

# %% [markdown]
# ## Polinomial transformation to increase model complexity

# %%
# Feature transformation
scaler = StandardScaler()
tranformer = PolynomialFeatures(degree=2)
pipe = make_pipeline(tranformer, scaler)

X_train_scaled = pipe.fit_transform(X_train.values)
X_test_scaled = pipe.transform(X_test.values)

# %%
# Train 
classifier = LinearRegression()
classifier.fit(X_train_scaled, y_train)
# R2 for train
R2_train = classifier.score(X_train_scaled, y_train)
R2_train
# Out:
# 0.7152401708573868

# %%
# Predict
y_pred = classifier.predict(X_test_scaled)
# R2 for test
R2_test = r2_score(y_test, y_pred)
R2_test
# Out:
# -1.3637810841315635e+24

# %%
# The model is overfitting train data that results in poor generalization. Explore regularization methods.

# %% [markdown]
# ## Models with regularization

# %% [markdown]
# ### Ridge

# %%
# Train 
classifier = RidgeCV(alphas=np.logspace(-2,3,100))
classifier.fit(X_train_scaled, y_train)
# R2 for train
R2_train = classifier.score(X_train_scaled, y_train)
R2_train
# Out:
# 0.6407887344745224

# %%
# Predict
y_pred = classifier.predict(X_test_scaled)
# R2 for test
R2_test = r2_score(y_test, y_pred)
print(R2_test)

rigde_coef = classifier.coef_
# Out:
# 0.528588790946519

# %%
# Ridge is performing better than a regression without regularization, still no improvement over the initial results.

# %% [markdown]
# ### Lasso

# %%
# Train 
classifier = LassoCV(random_state=7, alphas=np.logspace(-2,3,100))
classifier.fit(X_train_scaled, y_train)
# R2 for train
R2_train = classifier.score(X_train_scaled, y_train)
R2_train
# Out:
# /Users/greenapple/anaconda3/envs/metis/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.5791582478460274

# %%
# Predict
y_pred = classifier.predict(X_test_scaled)
# R2 for test
R2_test = r2_score(y_test, y_pred)
R2_test
# Out:
# 0.5218479631709922

# %%
# No improvement over the initial results.

# %% [markdown]
# ### ElasticNet

# %%
# Train 
classifier = ElasticNetCV(random_state=7, alphas=np.logspace(-2,3,100))
classifier.fit(X_train_scaled, y_train)
# R2 for train
R2_train = classifier.score(X_train_scaled, y_train)
R2_train
# Out:
# /Users/greenapple/anaconda3/envs/metis/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.6142730489895758

# %%
# Predict
y_pred = classifier.predict(X_test_scaled)
# R2 for test
R2_test = r2_score(y_test, y_pred)
R2_test
# Out:
# 0.524521638878924

# %%
# No improvement over the initial results.
# Overall, inclreasing the model complexity and subsequently using models with regularization 
# did not emprove the outcome.

# %% [markdown]
#  ## Power transformation to normalize features that have a scewed distribution

# %%
# Set features and target
X = df.loc[:,[      
    'guests', 
    'baths', 
    'beds',
    'bedrooms_inc',
    'review_rate', 
    'review_num',
    'Entire apartment', 
    'Entire guest suite', 
    'Entire house',
    'Private room in apartment', 
    'Private room in house',
    'ballard', 'beacon hill', 'burien', 'capitol hill','central district', 'delridge', 'downtown', 'fremont', 
    'green lake','lake city', 'lake union', 'magnolia', 'north seattle', 'northgate','phinney ridge', 
    'queen anne', 'rainier valley', 'shoreline','south end', 'tukwila', 'university district', 'west seattle',
    'white center'
]]

y = df['price_log']

# %%
# Feature transformation
scaler = StandardScaler()

power_transform = make_pipeline(PowerTransformer(), StandardScaler())

mapper = DataFrameMapper([
    (['review_num', 'review_rate', 'guests'], power_transform),
    (['baths', 'bedrooms_inc','beds', 
    'Entire apartment', 
    'Entire guest suite', 
    'Entire house',
    'Private room in apartment', 
    'Private room in house',
    'ballard', 'beacon hill', 'burien', 'capitol hill','central district', 'delridge', 'downtown', 'fremont', 
    'green lake','lake city', 'lake union', 'magnolia', 'north seattle', 'northgate','phinney ridge', 
    'queen anne', 'rainier valley', 'shoreline','south end', 'tukwila', 'university district', 'west seattle',
    'white center'], scaler)
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=10, shuffle=True)

# mapper.fit_transform(X)

# %%
pipe = make_pipeline(mapper, LinearRegression())
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

# %%
R2_train = pipe.score(X_train, y_train)
R2_train
# Out:
# 0.5916504771902213

# %%
R2_test = r2_score(y_test, y_pred)
R2_test
# Out:
# 0.5446921197296899

# %%
# Slightely better R2 for the test than linear regression without power transformation

# %% [markdown]
# ## Polinomial tranformation of  selected features

# %%
# Feature transformation
scaler = StandardScaler()
poli_transform = make_pipeline(PolynomialFeatures(degree=2), StandardScaler())

mapper = DataFrameMapper([
    (['review_num','review_rate','guests'], power_transform),
    (['guests', 'baths', 'bedrooms_inc','beds', 
    'Entire apartment', 
    'Entire guest suite', 
    'Entire house',
    'Private room in apartment', 
    'Private room in house',
    'ballard', 'beacon hill', 'burien', 'capitol hill','central district', 'delridge', 'downtown', 'fremont', 
    'green lake','lake city', 'lake union', 'magnolia', 'north seattle', 'northgate','phinney ridge', 
    'queen anne', 'rainier valley', 'shoreline','south end', 'tukwila', 'university district', 'west seattle',
    'white center'], scaler)
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=10, shuffle=True)

# mapper.fit_transform(X)

# %%
pipe = make_pipeline(mapper, LassoCV())
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
# Out:
# /Users/greenapple/anaconda3/envs/metis/lib/python3.7/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
R2_train = pipe.score(X_train, y_train)
R2_train
# Out:
# 0.5884579941800967

# %%
R2_test = r2_score(y_test, y_pred)
R2_test
# Out:
# 0.547499732863233

# %%
# Not a significant improvement of R2 score but is the best model trained so far. See linear regression
# with no feature manipulation with R2 = 0.5339798249000769.

# %% [markdown]
# ## Feature importance

# %%
# Set features and target
X = df.loc[:,[      
    'guests', 
    'baths', 
    'beds',
    'bedrooms_inc',
    'review_rate', 
    'review_num',
    'Entire apartment', 
    'Entire guest suite', 
    'Entire house',
    'Private room in apartment', 
    'Private room in house',
    'ballard', 'beacon hill', 'burien', 'capitol hill','central district', 'delridge', 'downtown', 'fremont', 
    'green lake','lake city', 'lake union', 'magnolia', 'north seattle', 'northgate','phinney ridge', 
    'queen anne', 'rainier valley', 'shoreline','south end', 'tukwila', 'university district', 'west seattle',
    'white center'
]]

y = df['price_log']

# %%
# Fit model
model = sm.OLS(y, X, data=df)

results = model.fit()

# Model summary
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              price_log   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     51.86
# Date:                Thu, 10 Oct 2019   Prob (F-statistic):          5.19e-201
# Time:                        21:34:10   Log-Likelihood:                 656.37
# No. Observations:                1235   AIC:                            -1247.
# Df Residuals:                    1202   BIC:                            -1078.
# Df Model:                          32
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# guests                        0.0126      0.004      2.919      0.004       0.004       0.021
# baths                         0.0636      0.010      6.515      0.000       0.044       0.083
# beds                         -0.0008      0.006     -0.118      0.906      -0.013       0.012
# bedrooms_inc                  0.0616      0.008      7.255      0.000       0.045       0.078
# review_rate                   0.1193      0.021      5.670      0.000       0.078       0.161
# review_num                -8.899e-05   4.04e-05     -2.200      0.028      -0.000   -9.63e-06
# Entire apartment              0.9734      0.083     11.743      0.000       0.811       1.136
# Entire guest suite            0.9119      0.084     10.832      0.000       0.747       1.077
# Entire house                  0.9579      0.084     11.469      0.000       0.794       1.122
# Private room in apartment     0.9128      0.088     10.378      0.000       0.740       1.085
# Private room in house         0.7509      0.083      9.019      0.000       0.588       0.914
# ballard                       0.2173      0.030      7.305      0.000       0.159       0.276
# beacon hill                   0.2075      0.032      6.393      0.000       0.144       0.271
# burien                        0.0820      0.034      2.411      0.016       0.015       0.149
# capitol hill                  0.2152      0.023      9.189      0.000       0.169       0.261
# central district              0.2388      0.023     10.529      0.000       0.194       0.283
# delridge                      0.1634      0.027      6.105      0.000       0.111       0.216
# downtown                      0.3070      0.020     15.471      0.000       0.268       0.346
# fremont                       0.2308      0.029      7.843      0.000       0.173       0.289
# green lake                    0.1864      0.039      4.805      0.000       0.110       0.262
# lake city                     0.1655      0.053      3.121      0.002       0.061       0.270
# lake union                    0.3008      0.021     14.462      0.000       0.260       0.342
# magnolia                      0.2617      0.036      7.326      0.000       0.192       0.332
# north seattle                 0.2061      0.026      8.004      0.000       0.156       0.257
# northgate                     0.1346      0.026      5.132      0.000       0.083       0.186
# phinney ridge                 0.1736      0.034      5.065      0.000       0.106       0.241
# queen anne                    0.2743      0.029      9.342      0.000       0.217       0.332
# rainier valley                0.1554      0.022      6.977      0.000       0.112       0.199
# shoreline                     0.1407      0.053      2.678      0.008       0.038       0.244
# south end                     0.1857      0.031      6.062      0.000       0.126       0.246
# tukwila                       0.0389      0.046      0.839      0.402      -0.052       0.130
# university district           0.2526      0.066      3.848      0.000       0.124       0.381
# west seattle                  0.2330      0.026      8.917      0.000       0.182       0.284
# white center                  0.1358      0.036      3.799      0.000       0.066       0.206
# ==============================================================================
# Omnibus:                       47.331   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.056
# Skew:                           0.149   Prob(JB):                     2.31e-26
# Kurtosis:                       4.485   Cond. No.                     1.25e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.3e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# Features
X = df.loc[:,[      
    'guests', 
    'baths', 
    'beds',
    'bedrooms_inc',
    'review_rate', 
    'review_num',
    'Entire apartment', 
    'Entire guest suite', 
    'Entire house',
    'Private room in apartment', 
    'Private room in house',
    'ballard', 'beacon hill', 'burien', 'capitol hill','central district', 'delridge', 'downtown', 'fremont', 
    'green lake','lake city', 'lake union', 'magnolia', 'north seattle', 'northgate','phinney ridge', 
    'queen anne', 'rainier valley', 'shoreline','south end', 'tukwila', 'university district', 'west seattle',
    'white center'
]]

y = df['price_log']

# %%
# Feature evaluation with Recirsive Feature Elimination
classifier = LinearRegression(normalize=True)
selector = RFE(classifier, step=1)
results = selector.fit(X, y)
support = results.support_
rank = results.ranking_
features = results.n_features_

# %%
# Pull together feature coefficients  and ranks
df_features = pd.DataFrame
df_features = pd.DataFrame(X.columns, columns=['features'])
df_features['rank'] = pd.DataFrame(rank)
df_features['support'] = pd.DataFrame(support) 
df_features['linreg_coef'] = pd.DataFrame(linreg_coef)
df_features['rigde_coef'] = pd.DataFrame(rigde_coef)

# %%
df_features
# Out:
#                      features  rank  support   linreg_coef  rigde_coef
# 0                      guests    16    False  2.779264e-02    0.000000
# 1                       baths    15    False  3.652953e-02    0.007475
# 2                        beds    17    False  5.081907e-03    0.007819
# 3                bedrooms_inc    14    False  5.420209e-02    0.004285
# 4                 review_rate    13    False  2.583990e-02    0.009548
# 5                  review_num    18    False -8.314869e-03    0.008055
# 6            Entire apartment     1     True  1.199954e+11   -0.001290
# 7          Entire guest suite     1     True  7.728563e+10    0.002636
# 8                Entire house     1     True  1.541554e+11    0.000568
# 9   Private room in apartment     1     True  5.136603e+10    0.005270
# 10      Private room in house     1     True  1.179093e+11   -0.000337
# 11                    ballard     1     True -2.082187e+10   -0.009799
# 12                beacon hill     1     True -1.694144e+10    0.000162
# 13                     burien    12    False -1.694144e+10   -0.001629
# 14               capitol hill     1     True -3.345854e+10   -0.002466
# 15           central district     1     True -3.384213e+10    0.000536
# 16                   delridge     6    False -2.372276e+10    0.000548
# 17                   downtown     1     True -4.589835e+10   -0.003529
# 18                    fremont     1     True -2.216513e+10    0.004054
# 19                 green lake     4    False -1.405677e+10    0.002486
# 20                  lake city     9    False -1.034654e+10   -0.000262
# 21                 lake union     1     True -4.086761e+10   -0.000461
# 22                   magnolia     1     True -1.604152e+10    0.002420
# 23              north seattle     2    False -2.828354e+10   -0.000680
# 24                  northgate    10    False -2.703946e+10   -0.001182
# 25              phinney ridge     3    False -1.779240e+10   -0.001694
# 26                 queen anne     1     True -2.183813e+10   -0.001007
# 27             rainier valley     5    False -3.513776e+10    0.001026
# 28                  shoreline     8    False -1.105528e+10   -0.003024
# 29                  south end     1     True -1.899134e+10    0.002312
# 30                    tukwila    11    False -1.171991e+10   -0.000371
# 31        university district     1     True -8.753330e+09   -0.001992
# 32               west seattle     1     True -2.852420e+10    0.000338
# 33               white center     7    False -1.604152e+10    0.000350

# %%
# Selected features to list
df_sel_features = df_features.loc[df_features['support'], ['features']]
sel_features = list(df_sel_features['features'])

# %%
new_features = sel_features + ['guests', 'beds', 'bedrooms_inc', 'review_rate', 'baths']

# %%
# Combine `Private room in apartment` and `Private room in house` in `private_room` feature 
df['private_room'] = df['Private room in apartment'] + df['Private room in house']

new_features.append('private_room')
new_features.remove('Private room in apartment')
new_features.remove('Private room in house')

# %%
# Combine `Entire house` and `Entire apartment` in `entire_place` feature 
df['entire_place'] = df['Entire house'] + df['Entire apartment']

new_features.append('entire_place')
new_features.remove('Entire house')
new_features.remove('Entire apartment')

# %%
new_features.remove('review_rate')

# %%
# Set features and target
X = df.loc[:, new_features]

y = df['price_log']

# %%
# Train linear regression with new_features
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=10, shuffle=True)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train.values)
X_test_scaled = scaler.transform(X_test.values)
    
# Train 
a = classifier = LinearRegression()
classifier.fit(X_train_scaled, y_train)
    
# R2 for train
R2_train = classifier.score(X_train_scaled, y_train)
print('R2 train: ', R2_train)

# Predict
y_pred = classifier.predict(X_test_scaled)
    
# R2 for test
R2_test = r2_score(y_test, y_pred)
print('R2 test: ', R2_test)
    
residuals = y_test - y_pred

linreg_coef = classifier.coef_
# Out:
# R2 train:  0.5464482525036498
# R2 test:  0.5158351563003858

# %%
X.columns.to_list()
# Out:
# ['Entire guest suite',
#  'ballard',
#  'beacon hill',
#  'capitol hill',
#  'central district',
#  'downtown',
#  'fremont',
#  'lake union',
#  'magnolia',
#  'queen anne',
#  'south end',
#  'university district',
#  'west seattle',
#  'guests',
#  'beds',
#  'bedrooms_inc',
#  'baths',
#  'private_room',
#  'entire_place']

# %% [markdown]
# ## Story telling

# %%
home_features = ['Entire guest suite', 'ballard', 'beacon hill', 'capitol hill',
       'central district', 'downtown', 'fremont', 'lake union', 'magnolia',
       'queen anne', 'south end', 'university district', 'west seattle',
       'guests', 'beds', 'bedrooms_inc', 'baths',
       'private_room', 'entire_place']

# %%
# Set features and target
X = df.loc[:, new_features]

y = df['price_log']

# %%
X.guests.value_counts()
# Out:
# 2.0     368
# 4.0     284
# 6.0     203
# 3.0     138
# 5.0      72
# 8.0      49
# 7.0      29
# 10.0     28
# 1.0      28
# 9.0      14
# 12.0     12
# 13.0      4
# 11.0      4
# 15.0      1
# 14.0      1
# Name: guests, dtype: int64

# %%
X.beds.value_counts()
# Out:
# 1.0    464
# 2.0    336
# 3.0    254
# 4.0     99
# 5.0     31
# 6.0     24
# 0.0     15
# 7.0     12
# Name: beds, dtype: int64

# %%
X.bedrooms_inc.value_counts()
# Out:
# 1.0    558
# 2.0    275
# 0.5    185
# 3.0    172
# 4.0     37
# 5.0      6
# 6.0      2
# Name: bedrooms_inc, dtype: int64

# %%
X.baths.value_counts()
# Out:
# 1.0    920
# 2.0    141
# 1.5     68
# 2.5     65
# 3.5     20
# 3.0     17
# 4.0      3
# 0.0      1
# Name: baths, dtype: int64

# %%
X.shape
# Out:
# (1235, 19)

# %%
hoods = [
 'ballard',
 'beacon hill',
 'capitol hill',
 'central district',
 'downtown',
 'fremont',
 'lake union',
 'magnolia',
 'queen anne',
 'south end',
 'university district',
 'west seattle'
]

place_type = [
    'private_room', 
    'entire_place',
    'Entire guest suite',   
]

beds = [0, 1, 2, 3, 4, 5, 6, 7]
bedrooms_inc = [0.5, 1, 2, 3, 4, 5]
baths = [0, 1, 2, 3, 4, 1.5, 2.5, 3.5]
guests = list(range(1, 15, 1))

# %%
df_fake = pd.DataFrame()
home_rows = []
for hood in hoods:
        for type_ in place_type:
            for bed in beds:
                for bath in baths:
                    for bedroom in bedrooms_inc:
                        for guest in guests:
                            home_row = {}
                            home_row['hoods'] = hood
                            home_row['place_type'] = type_
                            home_row['beds'] = bed
                            home_row['baths'] = bath
                            home_row['bedrooms_inc'] = bedroom
                            home_row['guests'] = guest
                            home_rows.append(home_row)

# %%
df_fake = pd.DataFrame(home_rows)

# %%
df_fake.shape
# Out:
# (193536, 6)

# %%
# Get dummies for `place_type`
df_fake = pd.concat([df_fake,pd.get_dummies(df_fake['place_type'])], axis=1)

# %%
df_fake.shape
# Out:
# (193536, 9)

# %%
# Get dummies for `hoods`
df_fake = pd.concat([df_fake,pd.get_dummies(df_fake['hoods'])], axis=1)

# %%
df_fake_pred = df_fake.copy()
df_fake_pred.drop(columns=['place_type', 'hoods'], inplace=True)
df_fake_pred.shape
# Out:
# (193536, 19)

# %%
df_fake_pred.shape
# Out:
# (193536, 19)

# %%
df_fake_pred.loc[df_fake_pred['private_room']==1] ['bedrooms_inc'].value_counts()
# Out:
# 3.0    10752
# 5.0    10752
# 4.0    10752
# 2.0    10752
# 1.0    10752
# 0.5    10752
# Name: bedrooms_inc, dtype: int64

# %%
df_fake_pred.loc[df_fake_pred['private_room']==1] ['guests'].value_counts()
# Out:
# 14    4608
# 13    4608
# 12    4608
# 11    4608
# 10    4608
# 9     4608
# 8     4608
# 7     4608
# 6     4608
# 5     4608
# 4     4608
# 3     4608
# 2     4608
# 1     4608
# Name: guests, dtype: int64

# %%
X.loc[X['bedrooms_inc']==1.0] ['guests'].value_counts()
# Out:
# 2.0    266
# 4.0    137
# 3.0     87
# 1.0     27
# 5.0     23
# 6.0     18
# Name: guests, dtype: int64

# %%
df_fake_pred.loc[df_fake_pred['private_room']==1] ['guests'].value_counts()
# Out:
# 14    4608
# 13    4608
# 12    4608
# 11    4608
# 10    4608
# 9     4608
# 8     4608
# 7     4608
# 6     4608
# 5     4608
# 4     4608
# 3     4608
# 2     4608
# 1     4608
# Name: guests, dtype: int64

# %%
X.loc[X['bedrooms_inc']==1.0] ['guests'].value_counts()
# Out:
# 2.0    266
# 4.0    137
# 3.0     87
# 1.0     27
# 5.0     23
# 6.0     18
# Name: guests, dtype: int64

# %%
df_fake_pred.loc[df_fake_pred['entire_place']==1] ['beds'].value_counts()
# Out:
# 7    7104
# 6    7104
# 5    7104
# 4    7104
# 3    7104
# 2    7104
# 1    7104
# 0    7104
# Name: beds, dtype: int64

# %%
# Removing combinations that are not compatible
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.private_room == 1)
                                              & (df_fake_pred.bedrooms_inc == 5.0)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.private_room == 1)
                                              & (df_fake_pred.bedrooms_inc == 4.0)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.private_room == 1)
                                              & (df_fake_pred.bedrooms_inc == 3.0)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.private_room == 1)
                                              & (df_fake_pred.bedrooms_inc == 2.0)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.private_room == 1)
                                              & (df_fake_pred.guests > 4)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 1.0)
                                              & (df_fake_pred.guests > 4)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.private_room == 1.0)
                                              & (df_fake_pred.beds > 4)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.private_room == 1.0)
                                              & (df_fake_pred.baths > 2)].index)

df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 0.5)
                                              & (df_fake_pred.baths > 1)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 0.5)
                                              & (df_fake_pred.guests > 4)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 0.5)
                                              & (df_fake_pred.beds > 3)].index)

df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 2.0)
                                              & (df_fake_pred.beds > 4)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 2.0)
                                              & (df_fake_pred.baths > 2)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 2.0)
                                              & (df_fake_pred.guests > 6)].index)


df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 3.0)
                                              & (df_fake_pred.beds > 6)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 3.0)
                                              & (df_fake_pred.guests > 10)].index)


df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 4.0)
                                              & (df_fake_pred.beds < 4)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 4.0)
                                              & (df_fake_pred.baths < 2)].index)
df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 4.0)
                                              & (df_fake_pred.guests < 4)].index)

df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.entire_place == 1)
                                              & (df_fake_pred.baths == 0.0)].index)

df_fake_pred = df_fake_pred.drop(df_fake_pred[(df_fake_pred.bedrooms_inc == 2.0)
                                              & (df_fake_pred.guests < 2)].index)

# look at num of beds in combinatipon with num of guests

# %%
df_fake_pred.shape
# Out:
# (47820, 19)

# %%
df_all_comb.columns
# Out:
# Index(['beds', 'baths', 'bedrooms_inc', 'guests', 'Entire guest suite',
#        'entire_place', 'private_room', 'ballard', 'beacon hill',
#        'capitol hill', 'central district', 'downtown', 'fremont', 'lake union',
#        'magnolia', 'queen anne', 'south end', 'university district',
#        'west seattle'],
#       dtype='object')

# %%
X.columns
# Out:
# Index(['Entire guest suite', 'ballard', 'beacon hill', 'capitol hill',
#        'central district', 'downtown', 'fremont', 'lake union', 'magnolia',
#        'queen anne', 'south end', 'university district', 'west seattle',
#        'guests', 'beds', 'bedrooms_inc', 'baths', 'private_room',
#        'entire_place'],
#       dtype='object')

# %%
df_fake_pred_scaled = scaler.transform(df_fake_pred.values)
price_all_comb = classifier.predict(df_fake_pred_scaled)

# %%
price_all_comb = np.power(10, price_all_comb)
# Out:
# /Users/greenapple/anaconda3/envs/metis/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in power
#   """Entry point for launching an IPython kernel.

# %%
type(price_all_comb)
# Out:
# numpy.ndarray

# %%
df_fake_pred_price = df_fake_pred.copy()
df_fake_pred_price['price_pred'] = price_all_comb

# %%
df_fake_pred_price['hoods'] = df_fake['hoods']
df_fake_pred_price['place_type'] = df_fake['place_type']

# %%
df_fake_pred_price.shape
# Out:
# (47820, 22)

# %%
# Predicted price distribution
df_fake_pred_price['price_pred'].replace([np.inf, -np.inf, 0], np.nan).hist()

# %%
df_fake_pred_price['price_pred'].replace([np.inf, -np.inf, 0], np.nan, inplace=True)

# %%
df_fake_pred_price.dropna(inplace=True)

# %%
df_fake_pred_price.shape
# Out:
# (5892, 22)

# %%
df_fake_pred_price.columns
# Out:
# Index(['beds', 'baths', 'bedrooms_inc', 'guests', 'Entire guest suite',
#        'entire_place', 'private_room', 'ballard', 'beacon hill',
#        'capitol hill', 'central district', 'downtown', 'fremont', 'lake union',
#        'magnolia', 'queen anne', 'south end', 'university district',
#        'west seattle', 'price_pred', 'hoods', 'place_type'],
#       dtype='object')

# %%
df_sub = df_fake_pred_price.loc[df_fake_pred_price['place_type']!='Entire guest suite']

# %%
df_sub.loc[df_sub['bedrooms_inc']==1.0].groupby(['hoods', 'place_type'])['price_pred'].agg('mean')
# Out:
# hoods                place_type
# ballard              entire_place    175.690707
#                      private_room    129.596531
# beacon hill          entire_place    167.116863
#                      private_room    123.202841
# capitol hill         entire_place    170.054698
#                      private_room    125.368688
# central district     entire_place    130.569740
#                      private_room     96.259364
# downtown             entire_place    156.303081
#                      private_room    115.230643
# fremont              entire_place    148.091469
#                      private_room    109.176832
# lake union           entire_place    125.531494
#                      private_room     92.545039
# magnolia             entire_place    121.983622
#                      private_room     89.929457
# queen anne           entire_place    140.469107
#                      private_room    103.557431
# south end            entire_place    138.937692
#                      private_room    102.428432
# university district  entire_place     86.155712
#                      private_room     63.518943
# west seattle         entire_place    136.395961
#                      private_room    100.561737
# Name: price_pred, dtype: float64

# %%
# Plot results and evaluations
sns.set(font_scale=1.5)
fig = sns.boxplot(x='hoods', y='price_pred', 
                  data=df_sub.loc[(df_sub['bedrooms_inc']==2.0) & 
                                  (df_sub['guests']<10) &
                                  (df_sub['hoods']=='ballard') &
                                   (df_sub['place_type']=='entire_place')],
                                  hue='guests')
plt.xlabel('Neighborhood')
plt.ylabel('Predicted price ($)')
plt.title('2 bedroom houses')
plt.savefig('guests.svg', bbox_inches = 'tight')
# plt.savefig('guests.svg') 
plt.show()

# %%
## # Plot results and evaluations
sns.set(font_scale=1.5)
fig = sns.boxplot(x='hoods', y='price_pred', 
                  data=df_sub.loc[(df_sub['place_type']=='entire_place') & 
                                (df_sub['hoods']=='university district') &
                                 (df_sub['bedrooms_inc']<5)],
                                 hue='bedrooms_inc')
# plt.legend(handles=['Studio', '1 bedroom', '2 bedroom', '3 bedroom'])
plt.xlabel('Neighborhood')
plt.ylabel('Predicted price')
plt.savefig('bedrooms.svg', bbox_inches = 'tight')
plt.show()

# %%
# Plot results and evaluations
fig = sns.boxplot(x='hoods', y='price_pred', 
                  data=df_sub.loc[(df_sub['bedrooms_inc']==1.0) & 
                                  (df_sub['guests']==2)],
                                  hue='place_type')

fig.set_xticklabels(fig.get_xticklabels(),rotation=30)
plt.xlabel('Neighborhood')
plt.ylabel('Predicted price')
# plt.savefig('mvp.svg') 
plt.show()

# %%
# Plot results and evaluations
sns.set(font_scale=1.5)
fig = sns.boxplot(x='hoods', y='price_pred', 
                  data=df_sub.loc[(df_sub['bedrooms_inc']==2.0) & 
                                  (df_sub['baths']<3) &
                                   (df_sub['hoods'].isin(['ballard','downtown', 'central district',
                                                          'university district']))],
                                  hue='baths', order=['ballard','downtown', 'central district',
                                                          'university district'])

fig.set_xticklabels(fig.get_xticklabels(),rotation=30)
plt.xlabel('Neighborhood')
plt.ylabel('Predicted price ($)')
plt.title('2 bedroom houses')
plt.savefig('baths.svg', bbox_inches = 'tight')
plt.show()

# %%
# Plot results and evaluations
sns.set(font_scale=1.3)
fig = sns.boxplot(x='hoods', y='price_pred', 
                  data=df_sub.loc[(df_sub['bedrooms_inc']==1.0) & 
                                  (df_sub['guests']==2) &
                                   (df_sub['hoods'].isin(['ballard','downtown', 'central district',
                                                          'university district']))],
                                  hue='place_type', order=['ballard','downtown', 'central district',
                                                          'university district'])

fig.set_xticklabels(fig.get_xticklabels(),rotation=30)
plt.xlabel('Neighborhood')
plt.ylabel('Predicted price ($)')
plt.title('entire place = 1 bedroom houses')
plt.savefig('hood.svg', bbox_inches = 'tight')
plt.show()
